# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Task1

# %%
df=pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df1=df[['title', 'genres']].head(50)
df1
# Out:
#                                           title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# ## Task 2

# %%
df2=df.isnull().sum()
df2
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
print(df.homepage.value_counts(),'\n')
print(df.homepage.mode()[0])
# Out:
# http://www.missionimpossible.com/                       4
# http://www.thehungergames.movie/                        4
# http://www.kungfupanda.com/                             3
# http://www.transformersmovie.com/                       3
# http://www.thehobbit.com/                               3
#                                                        ..
# http://www.ridealong.com/                               1
# http://www.theinternmovie.com/                          1
# http://www.miramax.com/movie/the-talented-mr-ripley/    1
# http://www.julieandjulia.com/                           1
# http://shanghaicalling.com/                             1
# Name: homepage, Length: 1691, dtype: int64
#
# http://www.missionimpossible.com/

# %%
df.homepage.isnull().sum()
# Out:
# 3091

# %%
print(df.tagline.value_counts(), '\n')
print(df.tagline.mode()[0])
# Out:
# Based on a true story.                          3
# From zero to hero.                              2
# The only way out is down.                       2
# Be careful what you wish for.                   2
# What could go wrong?                            2
#                                                ..
# Life is Not Child-Proof.                        1
# Every war has a beginning.                      1
# First came love... then came Reverend Frank.    1
# Get off the bench and get into the game.        1
# A New Yorker in Shanghai                        1
# Name: tagline, Length: 3944, dtype: int64
#
# Based on a true story.

# %%
df.tagline.isnull().sum()
# Out:
# 844

# %%
print(df.runtime.value_counts(), '\n')
runtime_mode=df.runtime.mode()[0]
runtime_mode
# Out:
# 90.0     163
# 100.0    149
# 98.0     140
# 97.0     133
# 95.0     123
#         ...
# 338.0      1
# 216.0      1
# 166.0      1
# 194.0      1
# 60.0       1
# Name: runtime, Length: 156, dtype: int64
# 90.0

# %%
df.runtime.isnull().sum()
# Out:
# 2

# %%
df.runtime=df.runtime.fillna(runtime_mode)
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
print(df.release_date.value_counts(), '\n')
release_date_mode=df.release_date.mode()[0]
release_date_mode
# Out:
# 01-01-2006    10
# 01-01-2002     8
# 03-09-2004     7
# 22-10-1999     7
# 18-07-2013     7
#               ..
# 30-12-2002     1
# 20-08-2002     1
# 05-11-1987     1
# 11-11-2004     1
# 03-05-2012     1
# Name: release_date, Length: 3280, dtype: int64
# '01-01-2006'

# %%
df.release_date.isnull().sum()
# Out:
# 1

# %%
df.release_date=df.release_date.fillna(release_date_mode)
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               0
# revenue                    0
# runtime                    0
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %% [markdown]
# ## Task 3

# %%
df3= df[(df.budget>220000)]
df3
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4680     450000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4682   13000000                     [{"id": 27, "name": "Horror"}]
# 4720    8500000                      [{"id": 18, "name": "Drama"}]
# 4758    4000000  [{"id": 53, "name": "Thriller"}, {"id": 878, "...
# 4770     500000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# ...

# %%
df3[['budget','genres']]
# Out:
#          budget                                             genres
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4680     450000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4682   13000000                     [{"id": 27, "name": "Horror"}]
# 4720    8500000                      [{"id": 18, "name": "Drama"}]
# 4758    4000000  [{"id": 53, "name": "Thriller"}, {"id": 878, "...
# 4770     500000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
#
# [3684 rows x 2 columns]

# %% [markdown]
# ## Task 4

# %%
df4=df[(df.revenue>961000000)]
df4.loc[:,['genres', 'revenue']]
# Out:
#                                                 genres     revenue
# 0    [{"id": 28, "name": "Action"}, {"id": 12, "nam...  2787965087
# 3    [{"id": 28, "name": "Action"}, {"id": 80, "nam...  1084939099
# 7    [{"id": 28, "name": "Action"}, {"id": 12, "nam...  1405403694
# 12   [{"id": 12, "name": "Adventure"}, {"id": 14, "...  1065659812
# 16   [{"id": 878, "name": "Science Fiction"}, {"id"...  1519557910
# 17   [{"id": 12, "name": "Adventure"}, {"id": 28, "...  1045713802
# 25   [{"id": 18, "name": "Drama"}, {"id": 10749, "n...  1845034188
# 26   [{"id": 12, "name": "Adventure"}, {"id": 28, "...  1153304495
# 28   [{"id": 28, "name": "Action"}, {"id": 12, "nam...  1513528810
# 29   [{"id": 28, "name": "Action"}, {"id": 12, "nam...  1108561013
# 31   [{"id": 28, "name": "Action"}, {"id": 12, "nam...  1215439994
# 32   [{"id": 10751, "name": "Family"}, {"id": 14, "...  1025491110
# 36   [{"id": 878, "name": "Science Fiction"}, {"id"...  1091405097
# ...

# %% [markdown]
# ## Task 5

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df5=df[['title','budget']]
df5
# Out:
#                                          title     budget
# 0                                       Avatar  237000000
# 1     Pirates of the Caribbean: At World's End  300000000
# 2                                      Spectre  245000000
# 3                        The Dark Knight Rises  250000000
# 4                                  John Carter  260000000
# ...                                        ...        ...
# 4798                               El Mariachi     220000
# 4799                                 Newlyweds       9000
# 4800                 Signed, Sealed, Delivered          0
# 4801                          Shanghai Calling          0
# 4802                         My Date with Drew          0
#
# [4803 rows x 2 columns]

# %%
df5.drop(df5[df5['budget']==0].index, inplace=True)
df5
# Out:
#                                          title     budget
# 0                                       Avatar  237000000
# 1     Pirates of the Caribbean: At World's End  300000000
# 2                                      Spectre  245000000
# 3                        The Dark Knight Rises  250000000
# 4                                  John Carter  260000000
# ...                                        ...        ...
# 4791                               Tin Can Man         13
# 4792                                      Cure      20000
# 4796                                    Primer       7000
# 4798                               El Mariachi     220000
# 4799                                 Newlyweds       9000
#
# [3766 rows x 2 columns]

# %%
df6=df[['title', 'revenue', 'genres']]
df6
# Out:
#                                          title     revenue  \
# 0                                       Avatar  2787965087
# 1     Pirates of the Caribbean: At World's End   961000000
# 2                                      Spectre   880674609
# 3                        The Dark Knight Rises  1084939099
# 4                                  John Carter   284139100
# ...                                        ...         ...
# 4798                               El Mariachi     2040920
# 4799                                 Newlyweds           0
# 4800                 Signed, Sealed, Delivered           0
# 4801                          Shanghai Calling           0
# 4802                         My Date with Drew           0
#
#                                                  genres
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
df6.drop(df6[df6['revenue']==0].index, inplace=True)
df6
# Out:
#                                          title     revenue  \
# 0                                       Avatar  2787965087
# 1     Pirates of the Caribbean: At World's End   961000000
# 2                                      Spectre   880674609
# 3                        The Dark Knight Rises  1084939099
# 4                                  John Carter   284139100
# ...                                        ...         ...
# 4775                               Funny Ha Ha       76901
# 4788                            Pink Flamingos     6000000
# 4792                                      Cure       99000
# 4796                                    Primer      424760
# 4798                               El Mariachi     2040920
#
#                                                  genres
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %% [markdown]
# ## Task 6

# %%
df_movies_revenue=df6.sort_values(by='revenue', ascending=False)
df_movies_revenue.head(10)
# Out:
#                           title     revenue  \
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 124                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 546                     Minions  1156730962
# 26   Captain America: Civil War  1153304495
#
#                                                 genres
# 0    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25   [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16   [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44                      [{"id": 28, "name": "Action"}]
# 7    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 124  [{"id": 16, "name": "Animation"}, {"id": 12, "...
# ...

# %%
df_movies=df5.sort_values('budget') 
df_movies.head(10)
# Out:
#                             title  budget
# 4247        Me You and Five Bucks       1
# 4251                Fetching Cody       1
# 4238                 Modern Times       1
# 4293                 The Algerian       1
# 4369                         Slam       1
# 4424                  Fear Clinic       1
# 4262        Incident at Loch Ness       1
# 4140  To Be Frank, Sinatra at 100       2
# 3967          Four Single Fathers       3
# 3687                  Without Men       4

# %% [markdown]
# ## Task7

# %%
popular_movies=df[['popularity', 'budget']]
popular_movies
# Out:
#       popularity     budget
# 0     150.437577  237000000
# 1     139.082615  300000000
# 2     107.376788  245000000
# 3     112.312950  250000000
# 4      43.926995  260000000
# ...          ...        ...
# 4798   14.269792     220000
# 4799    0.642552       9000
# 4800    1.444476          0
# 4801    0.857008          0
# 4802    1.929883          0
#
# [4803 rows x 2 columns]

# %%
import seaborn as sns

# %%
ax=sns.scatterplot(x='budget', y='popularity', data=popular_movies)
ax.set_title('Budget Vs Popularity');

# %%
ax=sns.lmplot(x='budget', y='popularity', data=popular_movies);

# %% [markdown]
# ## Task 8

# %%
prod_comp=df[['production_companies']]
prod_comp
# Out:
#                                    production_companies
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
# [4803 rows x 1 columns]

# %%
count_prod=prod_comp.value_counts()
count_prod
# Out:
# production_companies
# []                                                                                                                                         351
# [{"name": "Paramount Pictures", "id": 4}]                                                                                                   58
# [{"name": "Universal Pictures", "id": 33}]                                                                                                  45
# [{"name": "New Line Cinema", "id": 12}]                                                                                                     38
# [{"name": "Columbia Pictures", "id": 5}]                                                                                                    37
#                                                                                                                                           ...
# ...

# %% [markdown]
# ## Task 9

# %%
count_prod.head(25)
# Out:
# production_companies
# []                                                                                                                  351
# [{"name": "Paramount Pictures", "id": 4}]                                                                            58
# [{"name": "Universal Pictures", "id": 33}]                                                                           45
# [{"name": "New Line Cinema", "id": 12}]                                                                              38
# [{"name": "Columbia Pictures", "id": 5}]                                                                             37
# [{"name": "Metro-Goldwyn-Mayer (MGM)", "id": 8411}]                                                                  32
# [{"name": "Twentieth Century Fox Film Corporation", "id": 306}]                                                      31
# [{"name": "Warner Bros.", "id": 6194}]                                                                               27
# ...

# %% [markdown]
# ## Task 10

# %%
revenue_wise=df.sort_values(by='revenue', ascending=False)
fist_fivehundred=revenue_wise.head(500)
fist_fivehundred
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44    190000000                     [{"id": 28, "name": "Action"}]
# ...         ...                                                ...
# 1042   48000000                     [{"id": 35, "name": "Comedy"}]
# 41    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 521    60000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 397    85000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 1744   30000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
#
#                                       homepage      id  \
# 0                  http://www.avatarmovie.com/   19995
# ...

# %%
print(fist_fivehundred['budget'].describe())
print(fist_fivehundred['budget'].describe().apply(lambda p: '%.2f' % p))
# Out:
# count    5.000000e+02
# mean     1.028037e+08
# std      6.268914e+07
# min      0.000000e+00
# 25%      5.500000e+07
# 50%      9.500000e+07
# 75%      1.500000e+08
# max      3.800000e+08
# Name: budget, dtype: float64
# count          500.00
# mean     102803736.00
# std       62689144.25
# min              0.00
# 25%       55000000.00
# 50%       95000000.00
# 75%      150000000.00
# max      380000000.00
# Name: budget, dtype: object

# %%
plt.figure(figsize=(8,4))
sns.boxplot(fist_fivehundred.budget, color="g");

# %%
q1=fist_fivehundred['budget'].describe()['25%']
q3=fist_fivehundred['budget'].describe()['75%']
iqr=q3-q1

upper_bound=q3+1.5*iqr
fist_fivehundred['budget']=np.where(fist_fivehundred['budget']>upper_bound, upper_bound, 
                                       fist_fivehundred['budget'])

# %%
plt.figure(figsize=(8,4))
sns.boxplot(fist_fivehundred.budget, color="g");

# %%
print(fist_fivehundred['revenue'].describe())
print(fist_fivehundred['revenue'].describe().apply(lambda p: '%.2f' % p))
# Out:
# count    5.000000e+02
# mean     4.587221e+08
# std      2.684133e+08
# min      2.190765e+08
# 25%      2.814473e+08
# 50%      3.630016e+08
# 75%      5.471332e+08
# max      2.787965e+09
# Name: revenue, dtype: float64
# count           500.00
# mean      458722133.29
# std       268413280.88
# min       219076518.00
# 25%       281447346.25
# 50%       363001569.50
# 75%       547133157.50
# max      2787965087.00
# Name: revenue, dtype: object

# %%
plt.figure(figsize=(8,4))
sns.boxplot(fist_fivehundred.revenue, color="g");

# %%
q1=fist_fivehundred['revenue'].describe()['25%']
q3=fist_fivehundred['revenue'].describe()['75%']
iqr=q3-q1

upper_bound=q3+1.5*iqr
fist_fivehundred['revenue']=np.where(fist_fivehundred['revenue']>upper_bound, upper_bound, 
                                       fist_fivehundred['revenue'])

# %%
plt.figure(figsize=(8,4))
sns.boxplot(fist_fivehundred.revenue);

# %%
print(fist_fivehundred['runtime'].describe())
print(fist_fivehundred['runtime'].describe().apply(lambda p: '%.2f' % p))
# Out:
# count    500.00000
# mean     118.62600
# std       23.28378
# min       70.00000
# 25%      100.00000
# 50%      116.00000
# 75%      132.00000
# max      238.00000
# Name: runtime, dtype: float64
# count    500.00
# mean     118.63
# std       23.28
# min       70.00
# 25%      100.00
# 50%      116.00
# 75%      132.00
# max      238.00
# Name: runtime, dtype: object

# %%
plt.figure(figsize=(8,4))
sns.boxplot(fist_fivehundred.runtime, color="y");

# %%
q1=fist_fivehundred['runtime'].describe()['25%']
q3=fist_fivehundred['runtime'].describe()['75%']

iqr=q3-q1
upper_bound=q3+1.5*iqr

fist_fivehundred['runtime']=np.where(fist_fivehundred['runtime']>upper_bound, upper_bound,
                                     fist_fivehundred['runtime'])

# %%
plt.figure(figsize=(8,4))
sns.boxplot(fist_fivehundred.runtime, color="y");

# %% [markdown]
# ## Task 11

# %%
movie_names=fist_fivehundred[(fist_fivehundred.runtime>118.63)]
movie_names.loc[:,['title', 'runtime']]
# Out:
#                            title  runtime
# 0                         Avatar    162.0
# 25                       Titanic    180.0
# 16                  The Avengers    143.0
# 28                Jurassic World    124.0
# 44                     Furious 7    137.0
# ...                          ...      ...
# 1161          The Social Network    120.0
# 912   Interview with the Vampire    123.0
# 521                 The Terminal    128.0
# 397             It's Complicated    121.0
# 1744                  Knocked Up    129.0
#
# [232 rows x 2 columns]
